# %%
paragraph = """Artificial intelligence is becoming one of the most important technologies in the world because it is helping people, businesses, students, doctors,
engineers, and researchers solve many different kinds of problems in a faster and smarter way. In the past, most computer programs were written with fixed rules, and they
could only do exactly what the programmer told them to do, but today many AI systems can learn from data, understand patterns, make predictions, answer questions,
summarize documents, translate languages, and even generate human-like text. For example, when a student uploads a document into an AI study assistant, the system can read
the material, remove unnecessary words, identify important concepts, and generate useful answers from the content. However, before a machine learning or natural language
processing model can understand text properly, the text usually needs to be cleaned and prepared. This process may include converting the text into lowercase, removing
punctuation, splitting the sentence into tokens, removing stop words, applying stemming or lemmatization, and finally converting the words into numerical features.
Stop words are common words such as “the,” “is,” “and,” “in,” “to,” “of,” “for,” “with,” “a,” and “an” that often appear many times in a paragraph but may not always
add strong meaning to the main idea. When these words are removed, the remaining words can give a clearer view of the important topics in the text. For example, in a
sentence about building, deploying, and optimizing GenAI applications with LangChain, words like “building,” “deploying,” “optimizing,” “GenAI,” “applications,”
and “LangChain” are more meaningful than small connecting words like “and,” “with,” or “the.” This is why stop words removal is useful in many NLP tasks such as
search engines, sentiment analysis, document classification, chatbot development, recommendation systems, and text summarization."""

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
for i in range(len(sentences)):
  words = nltk.word_tokenize(sentences[i])
  words = [word for word in words if word not in set(stopwords.words('english'))]
  pos_tagged_words = nltk.pos_tag(words)
  print(pos_tagged_words)
# Out:
# [('Artificial', 'JJ'), ('intelligence', 'NN'), ('becoming', 'VBG'), ('one', 'CD'), ('important', 'JJ'), ('technologies', 'NNS'), ('world', 'NN'), ('helping', 'VBG'), ('people', 'NNS'), (',', ','), ('businesses', 'NNS'), (',', ','), ('students', 'NNS'), (',', ','), ('doctors', 'NNS'), (',', ','), ('engineers', 'NNS'), (',', ','), ('researchers', 'NNS'), ('solve', 'VBP'), ('many', 'JJ'), ('different', 'JJ'), ('kinds', 'NNS'), ('problems', 'NNS'), ('faster', 'RBR'), ('smarter', 'JJ'), ('way', 'NN'), ('.', '.')]
# [('In', 'IN'), ('past', 'NN'), (',', ','), ('computer', 'NN'), ('programs', 'NNS'), ('written', 'VBN'), ('fixed', 'VBN'), ('rules', 'NNS'), (',', ','), ('could', 'MD'), ('exactly', 'RB'), ('programmer', 'VB'), ('told', 'NN'), (',', ','), ('today', 'NN'), ('many', 'JJ'), ('AI', 'NNP'), ('systems', 'NNS'), ('learn', 'VBP'), ('data', 'NNS'), (',', ','), ('understand', 'NN'), ('patterns', 'NNS'), (',', ','), ('make', 'VBP'), ('predictions', 'NNS'), (',', ','), ('answer', 'NN'), ('questions', 'NNS'), (',', ','), ('summarize', 'JJ'), ('documents', 'NNS'), (',', ','), ('translate', 'NN'), ('languages', 'NNS'), (',', ','), ('even', 'RB'), ('generate', 'VB'), ('human-like', 'JJ'), ('text', 'NN'), ('.', '.')]
# [('For', 'IN'), ('example', 'NN'), (',', ','), ('student', 'NN'), ('uploads', 'NNS'), ('document', 'NN'), ('AI', 'NNP'), ('study', 'NN'), ('assistant', 'NN'), (',', ','), ('system', 'NN'), ('read', 'JJ'), ('material', 'NN'), (',', ','), ('remove', 'VB'), ('unnecessary', 'JJ'), ('words', 'NNS'), (',', ','), ('identify', 'VB'), ('important', 'JJ'), ('concepts', 'NNS'), (',', ','), ('generate', 'NN'), ('useful', 'JJ'), ('answers', 'NNS'), ('content', 'NN'), ('.', '.')]
# [('However', 'RB'), (',', ','), ('machine', 'NN'), ('learning', 'VBG'), ('natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('model', 'NN'), ('understand', 'VBP'), ('text', 'JJ'), ('properly', 'RB'), (',', ','), ('text', 'JJ'), ('usually', 'RB'), ('needs', 'VBZ'), ('cleaned', 'JJ'), ('prepared', 'JJ'), ('.', '.')]
# [('This', 'DT'), ('process', 'NN'), ('may', 'MD'), ('include', 'VB'), ('converting', 'VBG'), ('text', 'JJ'), ('lowercase', 'NN'), (',', ','), ('removing', 'VBG'), ('punctuation', 'NN'), (',', ','), ('splitting', 'VBG'), ('sentence', 'NN'), ('tokens', 'NNS'), (',', ','), ('removing', 'VBG'), ('stop', 'NN'), ('words', 'NNS'), (',', ','), ('applying', 'VBG'), ('stemming', 'VBG'), ('lemmatization', 'NN'), (',', ','), ('finally', 'RB'), ('converting', 'VBG'), ('words', 'NNS'), ('numerical', 'JJ'), ('features', 'NNS'), ('.', '.')]
# [('Stop', 'JJ'), ('words', 'NNS'), ('common', 'JJ'), ('words', 'NNS'), ('“', 'NN'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('”', 'NNP'), ('often', 'RB'), ('appear', 'VBP'), ('many', 'JJ'), ('times', 'NNS'), ('paragraph', 'VBP'), ('may', 'MD'), ('always', 'RB'), ('add', 'VB'), ('strong', 'JJ'), ('meaning', 'NN'), ('main', 'JJ'), ('idea', 'NN'), ('.', '.')]
# [('When', 'WRB'), ('words', 'NNS'), ('removed', 'VBD'), (',', ','), ('remaining', 'VBG'), ('words', 'NNS'), ('give', 'JJ'), ('clearer', 'NN'), ('view', 'NN'), ('important', 'JJ'), ('topics', 'NNS'), ('text', 'NN'), ('.', '.')]
# [('For', 'IN'), ('example', 'NN'), (',', ','), ('sentence', 'NN'), ('building', 'NN'), (',', ','), ('deploying', 'NN'), (',', ','), ('optimizing', 'VBG'), ('GenAI', 'NNP'), ('applications', 'NNS'), ('LangChain', 'NNP'), (',', ','), ('words', 'NNS'), ('like', 'IN'), ('“', 'NNP'), ('building', 'NN'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('deploying', 'NN'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('optimizing', 'NN'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('GenAI', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('applications', 'NNS'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('LangChain', 'NNP'), ('”', 'NNP'), ('meaningful', 'JJ'), ('small', 'JJ'), ('connecting', 'NN'), ('words', 'NNS'), ('like', 'IN'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), (',', ','), ('”', 'NNP'), ('“', 'NNP'), ('the.', 'NN'), ('”', 'NN'), ('This', 'DT'), ('stop', 'NN'), ('words', 'NNS'), ('removal', 'VBP'), ('useful', 'JJ'), ('many', 'JJ'), ('NLP', 'NNP'), ('tasks', 'NNS'), ('search', 'NN'), ('engines', 'NNS'), (',', ','), ('sentiment', 'NN'), ('analysis', 'NN'), (',', ','), ('document', 'NN'), ('classification', 'NN'), (',', ','), ('chatbot', 'NN'), ('development', 'NN'), (',', ','), ('recommendation', 'NN'), ('systems', 'NNS'), (',', ','), ('text', 'JJ'), ('summarization', 'NN'), ('.', '.')]
